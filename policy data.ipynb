# %%
import pandas as pd

# %%
url = 'https://healthdata.gov/sites/default/files/state_policy_updates_20200902_0936.csv'

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state_id      2525 non-null   object
#  1   county        1492 non-null   object
#  2   fips_code     1492 non-null   float64
#  3   policy_level  2525 non-null   object
#  4   date          2525 non-null   object
#  5   policy_type   2525 non-null   object
#  6   start_stop    2525 non-null   object
#  7   comments      2525 non-null   object
#  8   source        2525 non-null   object
#  9   total_phases  99 non-null     float64
# dtypes: float64(2), object(8)
# memory usage: 197.4+ KB

# %%
df.head()
# Out:
#   state_id     county  fips_code policy_level        date  \
# 0       CO        NaN        NaN        state  2020-03-20
# 1       LA        NaN        NaN        state  2020-03-23
# 2       MS  Jefferson    28063.0       county  2020-07-13
# 3       TX       King    48269.0       county  2020-07-03
# 4       NE      Sarpy    31153.0       county  2020-03-18
#
#                                          policy_type start_stop  \
# 0  Waived One Week Waiting Period For Unemploymen...      start
# 1  Modify Medicaid Requirements With 1135 Waivers...      start
# 2                                   Childcare (K-12)      start
# 3                                   Mask Requirement      start
# 4                                   Shelter in Place      start
#
#                                             comments  \
# 0  Other measures and details for this policy inc...
# 1  Other measures and details for this policy inc...
# 2  Policy_Details: Executive Order by Governor Ta...
# ...

# %%
# states included

df.state_id.unique()
# Out:
# array(['CO', 'LA', 'MS', 'TX', 'NE', 'NC', 'MN', 'IN', 'UT', 'IL', 'MD',
#        'MI', 'DC', 'ND', 'OH', 'GA', 'AK', 'RI', 'HI', 'MT', 'NY', 'SC',
#        'ME', 'CA', 'MO', 'VT', 'VA', 'AL', 'CT', 'WI', 'IA', 'KS', 'PA',
#        'KY', 'NM', 'FL', 'NH', 'WA', 'OK', 'NJ', 'SD', 'AZ', 'OR', 'NV',
#        'MA', 'WY', 'WV', 'AR', 'ID', 'DE', 'TN', 'GU', 'PR', 'VI', 'MP'],
#       dtype=object)

# %%
# policy types

df.policy_type.unique()
# Out:
# array(['Waived One Week Waiting Period For Unemployment Insurance',
#        'Modify Medicaid Requirements With 1135 Waivers Date Of CMS Approval',
#        'Childcare (K-12)', 'Mask Requirement', 'Shelter in Place',
#        'Allow Audio Only Telehealth',
#        'Allow Expand Medicaid Telehealth Coverage',
#        'Stop Initiation Of Evictions Overall Or Due To Covid Related Issues',
#        'Entertainment', 'Outdoor and Recreation',
#        'Stop Enforcement Of Evictions Overall Or Due To Covid Related Issues',
#        'Order Freezing Utility Shut Offs', 'Non-Essential Businesses',
#        'Nursing Homes', 'Food and Drink',
#        'Mandate Face Mask Use By All Individuals In Public Facing Businesses',
#        'Suspended Elective Medical Dental Procedures', 'Gyms',
#        'Resumed Elective Medical Procedures', 'Personal Care', 'Phase 4',
#        'Public Health Advisory System',
#        'Reopened ACA Enrollment Using a Special Enrollment Period',
# ...

# %%
dates = df.date.unique()
dates.sort()
print(dates)

# anomalous date 1899-12-30

# date range 2020-01-01 to 2020-08-30
# Out:
# ['1899-12-30' '2020-01-01' '2020-02-29' '2020-03-01' '2020-03-04'
#  '2020-03-05' '2020-03-06' '2020-03-07' '2020-03-08' '2020-03-09'
#  '2020-03-10' '2020-03-11' '2020-03-12' '2020-03-13' '2020-03-14'
#  '2020-03-15' '2020-03-16' '2020-03-17' '2020-03-18' '2020-03-19'
#  '2020-03-20' '2020-03-21' '2020-03-22' '2020-03-23' '2020-03-24'
#  '2020-03-25' '2020-03-26' '2020-03-27' '2020-03-28' '2020-03-29'
#  '2020-03-30' '2020-03-31' '2020-04-01' '2020-04-02' '2020-04-03'
#  '2020-04-04' '2020-04-05' '2020-04-06' '2020-04-07' '2020-04-08'
#  '2020-04-09' '2020-04-10' '2020-04-12' '2020-04-13' '2020-04-14'
#  '2020-04-15' '2020-04-16' '2020-04-17' '2020-04-18' '2020-04-19'
#  '2020-04-20' '2020-04-21' '2020-04-22' '2020-04-23' '2020-04-24'
#  '2020-04-25' '2020-04-26' '2020-04-27' '2020-04-28' '2020-04-29'
#  '2020-04-30' '2020-05-01' '2020-05-03' '2020-05-04' '2020-05-05'
#  '2020-05-06' '2020-05-07' '2020-05-08' '2020-05-09' '2020-05-10'
# ...

# %%
# all rows related to Mask Requirement policy type

df[df.policy_type.isin(['Mask Requirement'])]
# Out:
#      state_id        county  fips_code policy_level        date  \
# 3          TX          King    48269.0       county  2020-07-03
# 17         OH        Lorain    39093.0       county  2020-07-10
# 27         TX  Throckmorton    48447.0       county  2020-07-03
# 33         TX         Rains    48379.0       county  2020-07-03
# 54         TX       Roberts    48393.0       county  2020-07-03
# ...       ...           ...        ...          ...         ...
# 2434       OH      Franklin    39049.0       county  2020-07-08
# 2442       TX        Bailey    48017.0       county  2020-07-03
# 2450       OH        Summit    39153.0       county  2020-07-10
# 2515       TX         Foard    48155.0       county  2020-07-03
# 2522       TX        Morris    48343.0       county  2020-07-03
#
#            policy_type start_stop  \
# 3     Mask Requirement      start
# 17    Mask Requirement      start
# 27    Mask Requirement      start
# 33    Mask Requirement      start
# ...
